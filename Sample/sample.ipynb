# %%
# !pip install langchain
# !pip install langchain-community
# !pip install langchain-openai
# !pip install langchain-text-splitters
# !pip install faiss-cpu
# !pip install pypdf
# !pip install python-dotenv

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters.character import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings, ChatOpenAI


from langchain_classic.chains.retrieval_qa.base import RetrievalQA

# %%
from openai import OpenAI

client = OpenAI(
    api_key="INSERT_API_KEY_HERE"   # ← put your key here
)

# %%
loader = PyPDFLoader("Adheek_Resume.pdf")  # ← replace with your PDF name
documents = loader.load()

print("PDF Loaded Pages:", len(documents))
# Out:
# PDF Loaded Pages: 1

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,     # size of each text piece
    chunk_overlap=200    # small overlap to keep context
)

chunks = text_splitter.split_documents(documents)

print("Total Chunks Created:", len(chunks))
chunks[:1]  # preview first chunk
# Out:
# Total Chunks Created: 2
# ...

# %%
# !pip install sentence-transformers

from sentence_transformers import SentenceTransformer
from langchain_community.embeddings import HuggingFaceEmbeddings


embeddings = HuggingFaceEmbeddings(
    model_name="all-MiniLM-L6-v2"
)
vectorstore = FAISS.from_documents(chunks, embeddings)  
print("Vectorstore created with FAISS")
# Out:
# ...
# C:\Users\10139690\AppData\Local\Temp\ipykernel_15936\625856271.py:7: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(
# ...

# %%
# !pip install groq

# %%
# !pip install sentence-transformers

from sentence_transformers import SentenceTransformer
from langchain_community.embeddings import HuggingFaceEmbeddings


embeddings = HuggingFaceEmbeddings(
    model_name="all-MiniLM-L6-v2"
)
vectorstore = FAISS.from_documents(chunks, embeddings)  
print("Vectorstore created with FAISS")
# Out:
# ...
# C:\Users\10139690\AppData\Local\Temp\ipykernel_15936\625856271.py:7: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(
# ...

# %%
from groq import Groq
from langchain_core.language_models.llms import LLM

client = Groq(api_key="INSERT_API_KEY_HERE")  # <--- replace with your real key

class GroqLLM(LLM):
    model_name: str = "llama3-8b-8192"

    def _call(self, prompt, stop=None):
        response = client.chat.completions.create(
            model=self.model_name,
            messages=[{"role": "user", "content": prompt}]
        )
        return response.choices[0].message.content

    @property
    def _llm_type(self):
        return "groq-llm"

# Instantiate with NO ERRORS
llm = GroqLLM()

# %%
query = "Can you summarize the resume?"  # ← your question here
response = qa_chain.run(query)      
print("Response:", response)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[79], line 2
#       1 query = "Can you summarize the resume?"  # ← your question here
# ----> 2 response = qa_chain.run(query)
#       3 print("Response:", response)
#
# File c:\Users\10139690\Desktop\Rough\.venv\lib\site-packages\langchain_core\_api\deprecation.py:206, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     204     warned = True
#     205     emit_warning()
# --> 206 return wrapped(*args, **kwargs)
#
# File c:\Users\10139690\Desktop\Rough\.venv\lib\site-packages\langchain_classic\chains\base.py:632, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     630         msg = "`run` supports only one positional argument."
#     631         raise ValueError(msg)
# --> 632     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
# ...
